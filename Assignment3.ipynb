# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit579-pixel/SL-3/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/SL-3/Ass3/Employee_Salary_Dataset.csv")

# %%
df
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
df.mean()
# Out:
# <ipython-input-80-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# ID                  1.800000e+01
# Experience_Years    9.200000e+00
# Age                 3.548571e+01
# Salary              2.059147e+06
# dtype: float64

# %%
df.loc[:,'Age'].mean()
# Out:
# 35.48571428571429

# %%
df.mean(axis=1)[0:4]
# Out:
# <ipython-input-82-6447142f9231>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=1)[0:4]
# 0    62508.50
# 1    12506.00
# 2    42507.25
# 3     6257.00
# dtype: float64

# %%
df.median(axis=1)[0:4]
# Out:
# <ipython-input-83-ccd22b6541c9>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median(axis=1)[0:4]
# 0    16.5
# 1    11.5
# 2    13.0
# 3    13.0
# dtype: float64

# %%
df.mode(axis=1)[0:4]
# Out:
# <ipython-input-84-e62d220d1a18>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df.mode(axis=1)[0:4]
# <ipython-input-84-e62d220d1a18>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df.mode(axis=1)[0:4]
# <ipython-input-84-e62d220d1a18>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df.mode(axis=1)[0:4]
# <ipython-input-84-e62d220d1a18>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df.mode(axis=1)[0:4]
# <ipython-input-84-e62d220d1a18>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df.mode(axis=1)[0:4]
# <ipython-input-84-e62d220d1a18>:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   df.mode(axis=1)[0:4]
# ...

# %%
df.std(axis=1)[0:4]
# Out:
# <ipython-input-85-18b37211c5c6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis=1)[0:4]
# 0    124994.333900
# 1     24996.001694
# 2     84995.167190
# 3     12495.336570
# dtype: float64

# %%
df.groupby(['Gender'])['Salary'].mean()
# Out:
# Gender
# Female    2.054917e+06
# Male      2.063626e+06
# Name: Salary, dtype: float64

# %%
df.min()
# Out:
# ID                       1
# Experience_Years         1
# Age                     17
# Gender              Female
# Salary                3000
# dtype: object

# %%
df1=df.select_dtypes(include=['int64'])

# %%
df1
# Out:
#     ID  Experience_Years  Age    Salary
# 0    1                 5   28    250000
# 1    2                 1   21     50000
# 2    3                 3   23    170000
# 3    4                 2   22     25000
# 4    5                 1   17     10000
# 5    6                25   62   5001000
# 6    7                19   54    800000
# 7    8                 2   21      9000
# 8    9                10   36     61500
# 9   10                15   54    650000
# 10  11                 4   26    250000
# 11  12                 6   29   1400000
# 12  13                14   39   6000050
# 13  14                11   40    220100
# 14  15                 2   23      7500
# 15  16                 4   27     87000
# 16  17                10   34    930000
# 17  18                15   54   7900000
# 18  19                 2   21     15000
# 19  20                10   36    330000
# 20  21                15   54   6570000
# 21  22                 4   26     25000
# ...

# %%
range_df=df1.max()-df1.min()
range_df
# Out:
# ID                       34
# Experience_Years         26
# Age                      45
# Salary              9997000
# dtype: int64

# %%
gender_col=df.loc[:,'Gender']
gender_col
# Out:
# 0     Female
# 1       Male
# 2     Female
# 3       Male
# 4       Male
# 5       Male
# 6     Female
# 7     Female
# 8     Female
# 9     Female
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14      Male
# 15    Female
# 16    Female
# 17    Female
# 18      Male
# 19      Male
# 20      Male
# 21      Male
# 22      Male
# 23    Female
# 24    Female
# 25    Female
# 26      Male
# 27    Female
# 28    Female
# 29    Female
# 30      Male
# 31      Male
# 32    Female
# 33    Female
# 34      Male
# Name: Gender, dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc=OneHotEncoder()

# %%
enc_data = enc.fit_transform(df[['Gender']])

# %%
feature_names = enc.get_feature_names_out(['Gender'])

# %%
feature_names
dense_matrix = enc_data.toarray()

# %%
enc_df = pd.DataFrame(dense_matrix, columns=feature_names)
enc_df
df3 = pd.concat([df.select_dtypes(include=['int64']), enc_df], axis=1)
df3
# Out:
#     ID  Experience_Years  Age    Salary  Gender_Female  Gender_Male
# 0    1                 5   28    250000            1.0          0.0
# 1    2                 1   21     50000            0.0          1.0
# 2    3                 3   23    170000            1.0          0.0
# 3    4                 2   22     25000            0.0          1.0
# 4    5                 1   17     10000            0.0          1.0
# 5    6                25   62   5001000            0.0          1.0
# 6    7                19   54    800000            1.0          0.0
# 7    8                 2   21      9000            1.0          0.0
# 8    9                10   36     61500            1.0          0.0
# 9   10                15   54    650000            1.0          0.0
# 10  11                 4   26    250000            1.0          0.0
# 11  12                 6   29   1400000            0.0          1.0
# 12  13                14   39   6000050            0.0          1.0
# ...

# %% [markdown]
# 2.Problem Statement

# %%
from sklearn.datasets import load_iris


iris = load_iris()
iris
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
