# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit579-pixel/SL-3/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/SL-3/Ass1/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns.values
# Out:
# array(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'], dtype=object)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
df.sort_index(axis=1, ascending=False, inplace=True)

# %%
df.sort_values(by='SepalWidthCm')
# Out:
#              Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  \
# 60   Iris-versicolor           2.0            5.0           1.0
# 62   Iris-versicolor           2.2            6.0           1.0
# 119   Iris-virginica           2.2            6.0           1.5
# 68   Iris-versicolor           2.2            6.2           1.5
# 41       Iris-setosa           2.3            4.5           0.3
# ..               ...           ...            ...           ...
# 16       Iris-setosa           3.9            5.4           0.4
# 14       Iris-setosa           4.0            5.8           0.2
# 32       Iris-setosa           4.1            5.2           0.1
# 33       Iris-setosa           4.2            5.5           0.2
# 15       Iris-setosa           4.4            5.7           0.4
#
#      PetalLengthCm   Id
# 60             3.5   61
# 62             4.0   63
# 119            5.0  120
# 68             4.5   69
# 41             1.3   42
# ..             ...  ...
# ...

# %%
df.iloc[5]
# Out:
# Species          Iris-setosa
# SepalWidthCm             3.9
# SepalLengthCm            5.4
# PetalWidthCm             0.4
# PetalLengthCm            1.7
# Id                         6
# Name: 5, dtype: object

# %%
df[0:3]
# Out:
#        Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm  Id
# 0  Iris-setosa           3.5            5.1           0.2            1.4   1
# 1  Iris-setosa           3.0            4.9           0.2            1.4   2
# 2  Iris-setosa           3.2            4.7           0.2            1.3   3

# %%
df.loc[:,['PetalWidthCm','PetalLengthCm']]
# Out:
#      PetalWidthCm  PetalLengthCm
# 0             0.2            1.4
# 1             0.2            1.4
# 2             0.2            1.3
# 3             0.2            1.5
# 4             0.2            1.4
# ..            ...            ...
# 145           2.3            5.2
# 146           1.9            5.0
# 147           2.0            5.2
# 148           2.3            5.4
# 149           1.8            5.1
#
# [150 rows x 2 columns]

# %%
df.iloc[:150,:]
# Out:
#             Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm  \
# 0       Iris-setosa           3.5            5.1           0.2            1.4
# 1       Iris-setosa           3.0            4.9           0.2            1.4
# 2       Iris-setosa           3.2            4.7           0.2            1.3
# 3       Iris-setosa           3.1            4.6           0.2            1.5
# 4       Iris-setosa           3.6            5.0           0.2            1.4
# ..              ...           ...            ...           ...            ...
# 145  Iris-virginica           3.0            6.7           2.3            5.2
# 146  Iris-virginica           2.5            6.3           1.9            5.0
# 147  Iris-virginica           3.0            6.5           2.0            5.2
# 148  Iris-virginica           3.4            6.2           2.3            5.4
# 149  Iris-virginica           3.0            5.9           1.8            5.1
#
#       Id
# 0      1
# 1      2
# ...

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#        Species  SepalLengthCm
# 1  Iris-setosa            4.9
# 2  Iris-setosa            4.7
# 4  Iris-setosa            5.0

# %%
df[df.columns[2:4]].iloc[5:10]
# Out:
#    SepalLengthCm  PetalWidthCm
# 5            5.4           0.4
# 6            4.6           0.3
# 7            5.0           0.2
# 8            4.4           0.2
# 9            4.9           0.1

# %%
df.boxplot(column='PetalLengthCm')
plt.show()

# %% [markdown]
# Starting with data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df
# Out:
#             Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm  \
# 0       Iris-setosa           3.5            5.1           0.2            1.4
# 1       Iris-setosa           3.0            4.9           0.2            1.4
# 2       Iris-setosa           3.2            4.7           0.2            1.3
# 3       Iris-setosa           3.1            4.6           0.2            1.5
# 4       Iris-setosa           3.6            5.0           0.2            1.4
# ..              ...           ...            ...           ...            ...
# 145  Iris-virginica           3.0            6.7           2.3            5.2
# 146  Iris-virginica           2.5            6.3           1.9            5.0
# 147  Iris-virginica           3.0            6.5           2.0            5.2
# 148  Iris-virginica           3.4            6.2           2.3            5.4
# 149  Iris-virginica           3.0            5.9           1.8            5.1
#
#       Id
# 0      1
# 1      2
# ...

# %%
x=df.iloc[:,1:]
x
# Out:
#      SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm   Id
# 0             3.5            5.1           0.2            1.4    1
# 1             3.0            4.9           0.2            1.4    2
# 2             3.2            4.7           0.2            1.3    3
# 3             3.1            4.6           0.2            1.5    4
# 4             3.6            5.0           0.2            1.4    5
# ..            ...            ...           ...            ...  ...
# 145           3.0            6.7           2.3            5.2  146
# 146           2.5            6.3           1.9            5.0  147
# 147           3.0            6.5           2.0            5.2  148
# 148           3.4            6.2           2.3            5.4  149
# 149           3.0            5.9           1.8            5.1  150
#
# [150 rows x 5 columns]

# %%
sk = MinMaxScaler()
x_scale=sk.fit_transform(x)
x_norm=pd.DataFrame(x_scale)
x_norm
# Out:
#             0         1         2         3         4
# 0    0.625000  0.222222  0.041667  0.067797  0.000000
# 1    0.416667  0.166667  0.041667  0.067797  0.006711
# 2    0.500000  0.111111  0.041667  0.050847  0.013423
# 3    0.458333  0.083333  0.041667  0.084746  0.020134
# 4    0.666667  0.194444  0.041667  0.067797  0.026846
# ..        ...       ...       ...       ...       ...
# 145  0.416667  0.666667  0.916667  0.711864  0.973154
# 146  0.208333  0.555556  0.750000  0.677966  0.979866
# 147  0.416667  0.611111  0.791667  0.711864  0.986577
# 148  0.583333  0.527778  0.916667  0.745763  0.993289
# 149  0.416667  0.444444  0.708333  0.694915  1.000000
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
y=df['Species']
label=LabelEncoder()
y_transform=pd.DataFrame(label.fit_transform(y))
y_transform
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [150 rows x 1 columns]
